# %%
import requests
url = "https://api.census.gov/data.json"

# %%
req = requests.get(url)

# %%
data = req.json()

# %%
data['dataset'][3]['c_dataset'][0] 
#dictionary that selects the 'dataset' dataset, the 3rd item in that list, and then the first item in the c_dataset
# Out:
# 'cbp'

# %%
c_dataset = [item['c_dataset'] for item in data['dataset']]

# %%
c_dataset
# Out:
# [['cbp'],
#  ['zbp'],
#  ['cbp'],
#  ['cbp'],
#  ['cbp'],
#  ['cbp'],
#  ['zbp'],
#  ['cbp'],
#  ['pep', 'int_charagegroups'],
#  ['zbp'],
#  ['pep', 'int_natcivpop'],
#  ['pep', 'int_natresafo'],
#  ['pep', 'int_natrespop'],
#  ['cbp'],
#  ['sf1'],
#  ['sf3'],
#  ['zbp'],
#  ['cbp'],
#  ['cbp'],
#  ['cbp'],
#  ['cbp'],
#  ['ewks'],
#  ['cbp'],
#  ['nonemp'],
#  ['cbp'],
#  ['nonemp'],
#  ['zbp'],
#  ['cbp'],
#  ['nonemp'],
#  ['zbp'],
#  ['cbp'],
#  ['nonemp'],
#  ['pep', 'int_charage'],
#  ['pep', 'int_charagegroups'],
#  ['zbp'],
#  ['pep', 'int_housingunits'],
#  ['pep', 'int_natmonthly'],
#  ['pep', 'int_population'],
#  ['sf1'],
#  ['nonemp'],
#  ['sf3'],
#  ['surname'],
#  ['zbp'],
#  ['zbp'],
#  ['cbp'],
#  ['cbp'],
#  ['ewks'],
#  ['nonemp'],
#  ['cbp'],
#  ['acs', 'acs1', 'cprofile'],
#  ['nonemp'],
#  ['zbp'],
#  ['cbp'],
#  ['nonemp'],
#  ['zbp'],
#  ['cbp'],
#  ['nonemp'],
#  ['zbp'],
#  ['cbp'],
#  ['nonemp'],
#  ['zbp'],
#  ['cbp'],
#  ['ewks'],
#  ['nonemp'],
# ...

# %%
data.keys()
#shows you all the keys
# Out:
# dict_keys(['@context', '@id', '@type', 'conformsTo', 'describedBy', 'dataset'])

# %%
url = "https://api.github.com"

# %%
path = '/users/emilylam98/repos'
#url+path gives us the full url to personal repo

# %%
my_repos = requests.get(url+path).json()

# %%
my_repos
# Out:
# [{'id': 232765065,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMzI3NjUwNjU=',
#   'name': 'atom',
#   'full_name': 'emilylam98/atom',
#   'private': False,
#   'owner': {'login': 'emilylam98',
#    'id': 59685779,
#    'node_id': 'MDQ6VXNlcjU5Njg1Nzc5',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/59685779?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/emilylam98',
#    'html_url': 'https://github.com/emilylam98',
#    'followers_url': 'https://api.github.com/users/emilylam98/followers',
#    'following_url': 'https://api.github.com/users/emilylam98/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/emilylam98/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/emilylam98/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/emilylam98/subscriptions',
#    'organizations_url': 'https://api.github.com/users/emilylam98/orgs',
# ...

# %%
#in open, put file path
#file is a variable name 
#contents of repos.csv are saved under variable file 

with open('repos.csv') as file:
    repos = file.readlines()

# %%
repos
# Out:
# ['Name,Repo\n',
#  'Jonathan Bechtel,https://github.com/JonathanBechtel\n',
#  'Aoife Duna,https://github.com/aoifeduna\n',
#  'Christos Simos,https://github.com/simoschr\n',
#  'Brittani Kauf,https://github.com/brittanikauf\n',
#  'Stanford Turner,https://github.com/sturner08\n',
#  'Shelly Seroussi,https://github.com/sturner08\n',
#  'Shela Wu,https://github.com/misowu\n',
#  'Rishabh Chandra,https://github.com/rishabhchandra35\n',
#  '"Behrang ""Brian"" Bidadi",https://github.com/brianb888\n',
#  'Alec Schneider,https://github.com/Blitz33697\n',
#  'Taku Takamatsu,https://github.com/taku-takamatsu\n',
#  'Lindsey Gumann,https://github.com/lgumann\n',
#  'David Hurley,https://github.com/davehurl\n',
#  'Kina Abe,https://github.com/kinaabe57\n',
#  'Elyse Chu,https://github.com/elysechu\n',
#  'Michael Lawlor,https://github.com/lawlormj/sample_work\n',
#  'Emily Lam,https://github.com/emilylam98\n',
#  'Mike Golodner,https://github.com/mgolodner/ga_repo.git\n',
# ...
